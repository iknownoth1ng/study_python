# %% [markdown]
# # A chart

# %%
import numpy as np
from matplotlib import pyplot as plt

ys=200+np.random.randn(100)
x=[x for x in range(len(ys))]

plt.plot(x,ys,'-')
plt.fill_between(x,ys,195,where=(ys>195),facecolor='g',alpha=0.6)

plt.title('Fills and Alpha Example')
plt.show()

# %%
from infi.systray import SysTrayIcon
from PIL import Image, ImageDraw, ImageFont
import time
import psutil

image = "main.ico"
initialStart = True
systray = SysTrayIcon(image, "CPU/MEM")

while True:
    img = Image.new('RGBA', (50, 50), color=(255, 255, 255, 100))
    d = ImageDraw.Draw(img)
    d.rectangle((0, 25, 50, 50), fill=(39, 112, 229), outline=None)

    font_type = ImageFont.truetype("arial.ttf", 25)
    a = psutil.cpu_percent(interval=1, percpu=False)
    b = psutil.virtual_memory().percent
    d.text((0, 0), f"{a}\n{b}", fill=(255, 255, 255), font=font_type)

    img.save(image)

    if initialStart:
        systray.start()
        initialStart = False
    else:
        systray.update(icon=image)
    time.sleep(0.5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\study\vsworkspace\study_python\00Pratice\03os\test.ipynb Cell 3 in <cell line: 11>()
#      <a href='vscode-notebook-cell:/d%3A/study/vsworkspace/study_python/00Pratice/03os/test.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a> d.rectangle((0, 25, 50, 50), fill=(39, 112, 229), outline=None)
#      <a href='vscode-notebook-cell:/d%3A/study/vsworkspace/study_python/00Pratice/03os/test.ipynb#W2sZmlsZQ%3D%3D?line=14'>15</a> font_type = ImageFont.truetype("arial.ttf", 25)
# ---> <a href='vscode-notebook-cell:/d%3A/study/vsworkspace/study_python/00Pratice/03os/test.ipynb#W2sZmlsZQ%3D%3D?line=15'>16</a> a = psutil.cpu_percent(interval=1, percpu=False)
#      <a href='vscode-notebook-cell:/d%3A/study/vsworkspace/study_python/00Pratice/03os/test.ipynb#W2sZmlsZQ%3D%3D?line=16'>17</a> b = psutil.virtual_memory().percent
#      <a href='vscode-notebook-cell:/d%3A/study/vsworkspace/study_python/00Pratice/03os/test.ipynb#W2sZmlsZQ%3D%3D?line=17'>18</a> d.text((0, 0), f"{a}\n{b}", fill=(255, 255, 255), font=font_type)
#
# File d:\python\Anaconda3\lib\site-packages\psutil\__init__.py:1739, in cpu_percent(interval, percpu)
#    1737 if blocking:
#    1738     t1 = cpu_times()
# -> 1739     time.sleep(interval)
#    1740 else:
#    1741     t1 = _last_cpu_times
#
# KeyboardInterrupt:
